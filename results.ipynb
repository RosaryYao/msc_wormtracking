# %% [markdown]
# ## FGBG model

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
import numpy as np
import sys
import time
import pandas as pd
import cv2
import os
import imageio
import matplotlib as mpl
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import shutil

# %%
m1_train_accuracy = [0.9358, 0.9719, 0.9797]
m2_train_accuracy = [0.9521, 0.9742, 0.9801]

# %%
m1_val_accuracy = [0.5238, 0.9661, 0.9921]
m2_val_accuracy = [0.3529, 0.9714, 0.9954]

# %%
m1_train_loss = [0.1975, 0.1218, 0.1098]
m2_train_loss = [0.1768, 0.1224, 0.1038]

# %%
m1_val_loss = [0.6789, 0.271, 0.2539]
m2_val_loss = [1.5041, 0.2386, 0.2888]

# %%
total_train_loss = [0.3925, 0.2625, 0.2319]
total_val_loss = [2.2013, 0.5279, 0.561]

# %%
import matplotlib.font_manager as font_manager
from matplotlib.pyplot import figure

font = font_manager.FontProperties(family='serif',
                                   style='normal', size=11)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

plt.plot([1,2,3], m1_train_accuracy, color='tab:blue', label="Model 1 training accuracy")
plt.plot([1,2,3], m2_train_accuracy, color='tab:orange', label="Model 2 training accuracy")
plt.plot([1,2,3], m1_val_accuracy, color='tab:green', label="Model 1 validation accuracy")
plt.plot([1,2,3], m2_val_accuracy, color='tab:red', label="Model 2 validation accuracy")
plt.xlim(0.8, 3.2)
plt.ylim(0.3,1.03)

csfont = {'fontname':'serif'}
hfont = {'fontname':'serif'}

plt.title('Accuracy of FGBF Model 1 and 2',**csfont)
plt.xlabel('Epoch', **hfont, fontsize=12)
plt.ylabel('Accuracy', **hfont, fontsize=12)
plt.legend(prop=font)
plt.xticks([1,2,3], **hfont)
plt.legend(prop=font, bbox_to_anchor=(1.04,1), borderaxespad=0)

#ax.set_aspect(1.0/ax.get_data_ratio(), adjustable='box')
plt.savefig('pics/results/fgbg_accuracy.png')

figure(figsize=(8, 6), dpi=80)
plt.show()

# %%
import matplotlib.font_manager as font_manager
from matplotlib.pyplot import figure

font = font_manager.FontProperties(family='serif',
                                   style='normal', size=11)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

plt.plot([1,2,3], m1_train_loss, color='tab:blue', label="Model 1 training loss")
plt.plot([1,2,3], m2_train_loss, color='tab:orange', label="Model 2 training loss")
plt.plot([1,2,3], m1_val_loss, color='tab:green', label="Model 1 validation loss")
plt.plot([1,2,3], m2_val_loss, color='tab:red', label="Model 2 validation loss")
plt.plot([1,2,3], total_train_loss, color='tab:purple', label="Training total loss")
plt.plot([1,2,3], total_val_loss, color='tab:cyan', label="Validation  total loss")
plt.xlim(0.8, 3.2)
plt.ylim(0,2.5)

csfont = {'fontname':'serif'}
hfont = {'fontname':'serif'}

plt.title('Loss of FGBF Model 1 and 2',**csfont)
plt.xlabel('Epoch', **hfont, fontsize=12)
plt.ylabel('Loss', **hfont, fontsize=12)
plt.legend(prop=font)
plt.xticks([1,2,3], **hfont)
plt.legend(prop=font, bbox_to_anchor=(1.04,1), borderaxespad=0)

#ax.set_aspect(1.0/ax.get_data_ratio(), adjustable='box')
plt.savefig('pics/results/fgbg_loss.png')

figure(figsize=(8, 6), dpi=80)
plt.show()

# %% [markdown]
# ## Pixel-wise model

# %%
m1_train_accuracy = [0.9073,0.9717,0.9642,0.9783,0.9672]
m2_train_accuracy = [0.9134,0.9735,0.9676,0.9789,0.9692]

m1_val_accuracy = [0.9687,0.9816,0.9789,0.9896,0.9843]
m2_val_accuracy = [0.9577,0.9857,0.9838,0.9925,0.9855]

# %%
m1_train_loss = [0.3422,0.2213,0.2094,0.174,0.1965]
m2_train_loss = [0.3624,0.2189,0.1968,0.167,0.1853]

m1_val_loss = [0.3912,0.3196,0.4231,0.3187,0.3088]
m2_val_loss = [0.3269,0.3219,0.374,0.321,0.318,]

total_train_loss = [0.7411,0.4767,0.4426,0.3776,0.4184]
total_val_loss = [0.7545,0.6779,0.8336,0.6762,0.6636]

# %%
import matplotlib.font_manager as font_manager
from matplotlib.pyplot import figure

font = font_manager.FontProperties(family='serif',
                                   style='normal', size=11)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

plt.plot([1,2,3,4,5], m1_train_accuracy, color='tab:blue', label="Model 1 training accuracy")
plt.plot([1,2,3,4,5], m2_train_accuracy, color='tab:orange', label="Model 2 training accuracy")
plt.plot([1,2,3,4,5], m1_val_accuracy, color='tab:green', label="Model 1 validation accuracy")
plt.plot([1,2,3,4,5], m2_val_accuracy, color='tab:red', label="Model 2 validation accuracy")
plt.xlim(0.8, 5.3)
plt.ylim(0.85,1.01)

csfont = {'fontname':'serif'}
hfont = {'fontname':'serif'}

plt.title('Accuracy of Pixel-wise Model 1 and 2',**csfont)
plt.xlabel('Epoch', **hfont, fontsize=12)
plt.ylabel('Accuracy', **hfont, fontsize=12)
plt.legend(prop=font, loc = "lower right")
plt.xticks([1,2,3,4,5], **hfont)
plt.legend(prop=font, bbox_to_anchor=(1.04,1), borderaxespad=0)

#ax.set_aspect(1.0/ax.get_data_ratio(), adjustable='box')
plt.savefig('pics/results/pixelwise_accuracy.png')

figure(figsize=(8, 6), dpi=80)
plt.show()

# %%
import matplotlib.font_manager as font_manager
from matplotlib.pyplot import figure

font = font_manager.FontProperties(family='serif',
                                   style='normal', size=11)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

plt.plot([1,2,3,4,5], m1_train_loss, color='tab:blue', label="Model 1 training loss")
plt.plot([1,2,3,4,5], m2_train_loss, color='tab:orange', label="Model 2 training loss")
plt.plot([1,2,3,4,5], m1_val_loss, color='tab:green', label="Model 1 validation loss")
plt.plot([1,2,3,4,5], m2_val_loss, color='tab:red', label="Model 2 validation loss")
plt.plot([1,2,3,4,5], total_train_loss, color='tab:purple', label="Total training loss")
plt.plot([1,2,3,4,5], total_val_loss, color='tab:cyan', label="Total validation loss")
plt.xlim(0.8, 5.3)
plt.ylim(0,1.01)

csfont = {'fontname':'serif'}
hfont = {'fontname':'serif'}

plt.title('Loss of Pixel-wise Model 1 and 2',**csfont)
plt.xlabel('Epoch', **hfont, fontsize=12)
plt.ylabel('Loss', **hfont, fontsize=12)
#plt.legend(prop=font, loc = "lower right")
plt.legend(prop=font, bbox_to_anchor=(1.04,1), borderaxespad=0)
plt.xticks([1,2,3,4,5], **hfont)

#ax.set_aspect(1.0/ax.get_data_ratio(), adjustable='box')
plt.savefig('pics/results/pixelwise_loss.png', bbox_inches = 'tight')

figure(figsize=(8, 6), dpi=80)
plt.show()

# %% [markdown]
# ## Some Tierpsy failures...

# %%
import numpy as np

# %%
w_6819_1_a6_1_raw = np.load("../22956819/A6_raw_1.npy")
w_6819_1_a6_1_mask = np.load("../22956819/A6_mask_1.npy")
w_6819_1_a6_1_seg = np.load("../22956819/A6_seg_1.npy")

# %%
plt.imshow(w_6819_1_a6_1_raw[10][200:400, 0:200])

# %%
w_6819_1_a6_1_mask.shape
# Out:
# (100, 530, 530, 1)

# %%
plt.imshow(w_6819_1_a6_1_mask[10][200:400, 0:200])

# %%
array=np.copy(w_6819_1_a6_1_seg[10])

mpl.rcParams['image.interpolation'] = 'none'  # Prevent mpl smoothes the edges
    
array[0:2, 0:2] = 10
array[528:530, 528:530] = 1

mask = array
mask = np.where(mask==0, -1, mask)

value = -1
masked_array = np.ma.masked_where(mask == value, mask)
cmap = mpl.cm.get_cmap("tab20").copy()
cmap.set_bad(color='black')
plt.imshow(masked_array[200:400, 0:200], cmap=cmap)

# %% [markdown]
# ## Touching the wall

# %%
# 6814_C3_1: 0 -> 599; 531 -> 1130

mask_1 = np.load("../22956814/C3_mask_1.npy")
mask_3 = np.load("../22956814/C3_mask_3.npy")

raw_1 = np.load("../22956814/C3_raw_1.npy")
raw_3 = np.load("../22956814/C3_raw_3.npy")

# %%
mpl.rcParams['image.interpolation'] = 'none'
plt.axis('off')
plt.imshow(mask_1[2])

# %%
plt.axis('off')
plt.imshow(raw_1[0])

# %%
# With contamination

# %%
x = np.load("../6819_3/D7_raw_1.npy")
mask = np.load("../6819_3/D7_mask_1.npy")
seg = np.load("../6819_3/D7_seg_1.npy")

# %%
#--------------------------------------------------------------------------

# %%
# Move to well edge

# %%
x_1 = np.load("../22956814/C3_raw_1.npy")
mask_1 = np.load("../22956814/C3_mask_1.npy")
seg_1 = np.load("../22956814/C3_seg_1.npy")

# %%
plt.imshow(mask_1[99])

# %%
x_3 = np.load("../22956814/C3_raw_3.npy")
mask_3 = np.load("../22956814/C3_mask_3.npy")
seg_3 = np.load("../22956814/C3_seg_3.npy")

# %%
plt.imshow(x_3[-1])

# %%
array = np.array(mask_3[-1])

uniques_original = list(np.unique(array))[1:]  # [1:] to omit values == '0'
print('unique_worm_ids: ', uniques_original)
#sequential_ids = range(50, len(uniques_original)+50)

sequential_ids = [99, 70]  # Manually set... to keep colors concsistent... 

array[0:2, 0:2] = 100
array[529:530, 529:530] = 1

for i, original in enumerate(uniques_original):
    array[array == uniques_original[i]] = sequential_ids[i]  # Update stacked_array with sequential worm_ids
print('sequential ids: ', list(np.unique(array))[1:])

plt.imshow(array)
# Out:
# unique_worm_ids:  [38, 530]
# sequential ids:  [1, 70, 99, 100]

# %%
# using gif.plot_pic
import gif
gif.plot_pic(seg_1[20], "pics/6814_1/C3_seg_1_frame20.jpg", raw=False, sequential=False)

# %%
# using gif.plot_pic
import gif
gif.plot_pic(seg_3[-1], "pics/6814_1/C3_seg_3_frame1130.jpg", raw=False, sequential=False)

# %%
# Contamination - 6819_3 D7 1

raw = np.load("../6819_3/D7_raw_1.npy")
mask = np.load("../6819_3/D7_mask_1.npy")
seg = np.load("../6819_3/D7_seg_1.npy")

# %%
#mpl.rcParams['image.interpolation'] = 'none'
plt.imshow(raw[0][50:150, 150:250])

# %%
mpl.rcParams['image.interpolation'] = 'none'
plt.imshow(mask[0][50:150, 150:250])

# %%
plt.imshow(seg[0])

# %%
array=np.copy(seg[0])

mpl.rcParams['image.interpolation'] = 'none'  # Prevent mpl smoothes the edges
    
array[0:2, 0:2] = 10
array[528:530, 528:530] = 1

mask = array
mask = np.where(mask==0, -1, mask)

value = -1
masked_array = np.ma.masked_where(mask == value, mask)
cmap = mpl.cm.get_cmap("tab20").copy()
cmap.set_bad(color='black')
plt.imshow(masked_array[50:150, 150:250], cmap=cmap)

# %%
# 22956814 C3 track

c3 = np.load("../22956814/C3_track_3.npy")

# %%
array=np.copy(c3[0])

mpl.rcParams['image.interpolation'] = 'none'  # Prevent mpl smoothes the edges
    
array[0:2, 0:2] = 10
array[528:530, 528:530] = 1

mask = array
mask = np.where(mask==0, -1, mask)

value = -1
track_array = np.ma.masked_where(mask == value, mask)
cmap = mpl.cm.get_cmap("tab20").copy()
cmap.set_bad(color='white')
plt.imshow(track_array, cmap=cmap)

# %%
array=np.copy(c3[3])

mpl.rcParams['image.interpolation'] = 'none'  # Prevent mpl smoothes the edges
    
array[0:2, 0:2] = 10
array[528:530, 528:530] = 1

mask = array
mask = np.where(mask==0, -1, mask)

value = -1
track_array = np.ma.masked_where(mask == value, mask)
cmap = mpl.cm.get_cmap("tab20").copy()
cmap.set_bad(color='white')
plt.imshow(track_array, cmap=cmap)

# %%
c3_seg = np.load("../22956814/C3_seg_1.npy")

# %%
array=np.copy(c3_seg[3])

mpl.rcParams['image.interpolation'] = 'none'  # Prevent mpl smoothes the edges
    
array[0:2, 0:2] = 10
array[528:530, 528:530] = 1

mask = array
mask = np.where(mask==0, -1, mask)

value = -1
track_array = np.ma.masked_where(mask == value, mask)
cmap = mpl.cm.get_cmap("tab20").copy()
cmap.set_bad(color='black')
plt.imshow(track_array, cmap=cmap)

# %%
c3_raw = np.load("../22956814/C3_raw_1.npy")

# %%
plt.imshow(c3_raw[3])

# %% [markdown]
# ## Tracking

# %%
seg = np.load("../22956819/A6_seg_4.npy")
track = np.load("../22956819/A6_track_4.npy")

# %%
np.unique(seg)
# Out:
# array([0, 1, 2, 3], dtype=int32)

# %%
array=np.copy(seg[50])

mpl.rcParams['image.interpolation'] = 'none'  # Prevent mpl smoothes the edges
    
array[0:2, 0:2] = 10
array[528:530, 528:530] = 1

mask = array
mask = np.where(mask==0, -1, mask)

value = -1
track_array = np.ma.masked_where(mask == value, mask)
cmap = mpl.cm.get_cmap("tab20").copy()
cmap.set_bad(color='black')
plt.imshow(track_array, cmap=cmap)

# %%
raw = np.load("../22956819/A6_raw_4.npy")
mask = np.load("../22956819/A6_mask_4.npy")

# %%
plt.imshow(raw[50])

# %%
np.unique(mask)
# Out:
# array([  0, 123], dtype=int32)
