# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
import numpy as np
import sys
import time
import pandas as pd
import cv2
import os
import imageio
import matplotlib as mpl
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from deepcell.utils.tracking_utils import trks_stats, save_trks

import masks
import gif
import raw
import lineage
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow-2.5.0-py3.7-linux-x86_64.egg/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
# Input file
fN = h5py.File("../22956814/22956814_featuresN.hdf5")

# Define dorsal and ventral coordinates
coordinates = fN['coordinates']
dorsal = coordinates['dorsal_contours']
ventral = coordinates['ventral_contours']

# trajectory_data and timeseries_data
traj = pd.read_hdf("../22956814/22956814_featuresN.hdf5", '/trajectories_data')
timeseries = fN['timeseries_data']

# %%
# Get wells - data from timeseries_data, at position [2]

wells = ['A1', 'A2', 'A3', 'A4', 'B1', 'B2', 'B3', 'B4', 'C1', 'C2', 'C3', 'C4', 'D1', 'D2', 'D3', 'D4']
#wells = [each.encode() for each in wells]

well_dict = {}
for each in wells:
    well_dict[each] = []
    
#print('A1'.encode().decode())
for i, each in enumerate(timeseries[:]):  # "i" == index
    well = each[2].decode()
    if well in well_dict.keys():
        well_dict[well].append(i)

# %%
# lineages

from lineage import make_lineage

a1_1 = make_lineage(traj, well_dict, 'A1', '22956814', "../22956814/A1_mask_seq_1.npy", 1) 

# Well A2
a2_1 = make_lineage(traj, well_dict, 'A2', '22956814', "../22956814/A2_mask_seq_1.npy", 1) 
a2_2 = make_lineage(traj, well_dict, 'A2', '22956814', "../22956814/A2_mask_seq_2.npy", 2) 
a2_3 = make_lineage(traj, well_dict, 'A2', '22956814', "../22956814/A2_mask_seq_3.npy", 3) 
a2_4 = make_lineage(traj, well_dict, 'A2', '22956814', "../22956814/A2_mask_seq_4.npy", 4) 
a2_5 = make_lineage(traj, well_dict, 'A2', '22956814', "../22956814/A2_mask_seq_5.npy", 5) 

# Well A3
a3_1 = make_lineage(traj, well_dict, 'A3', '22956814', "../22956814/A3_mask_seq_1.npy", 1) 
a3_2 = make_lineage(traj, well_dict, 'A3', '22956814', "../22956814/A3_mask_seq_2.npy", 2) 
a3_3 = make_lineage(traj, well_dict, 'A3', '22956814', "../22956814/A3_mask_seq_3.npy", 3) 
a3_4 = make_lineage(traj, well_dict, 'A3', '22956814', "../22956814/A3_mask_seq_4.npy", 4) 
a3_5 = make_lineage(traj, well_dict, 'A3', '22956814', "../22956814/A3_mask_seq_5.npy", 5) 

# Well A4
a4_1 = make_lineage(traj, well_dict, 'A4', '22956814', "../22956814/A4_mask_seq_1.npy", 1) 
a4_2 = make_lineage(traj, well_dict, 'A4', '22956814', "../22956814/A4_mask_seq_2.npy", 2) 
a4_3 = make_lineage(traj, well_dict, 'A4', '22956814', "../22956814/A4_mask_seq_3.npy", 3) 
a4_4 = make_lineage(traj, well_dict, 'A4', '22956814', "../22956814/A4_mask_seq_4.npy", 4) 
a4_5 = make_lineage(traj, well_dict, 'A4', '22956814', "../22956814/A4_mask_seq_5.npy", 5)

b1_1 = make_lineage(traj, well_dict, 'B1', '22956814', "../22956814/B1_mask_seq_1.npy", 1)

b2_1 = make_lineage(traj, well_dict, 'B2', '22956814', "../22956814/B2_mask_seq_1.npy", 1)
b2_2 = make_lineage(traj, well_dict, 'B2', '22956814', "../22956814/B2_mask_seq_2.npy", 2)

b3_1 = make_lineage(traj, well_dict, 'B3', '22956814', "../22956814/B3_mask_seq_1.npy", 1)
b3_2 = make_lineage(traj, well_dict, 'B3', '22956814', "../22956814/B3_mask_seq_2.npy", 2)
b3_3 = make_lineage(traj, well_dict, 'B3', '22956814', "../22956814/B3_mask_seq_3.npy", 3)
b3_4 = make_lineage(traj, well_dict, 'B3', '22956814', "../22956814/B3_mask_seq_4.npy", 4)
b3_5 = make_lineage(traj, well_dict, 'B3', '22956814', "../22956814/B3_mask_seq_5.npy", 5)
b3_6 = make_lineage(traj, well_dict, 'B3', '22956814', "../22956814/B3_mask_seq_6.npy", 6)
b3_7 = make_lineage(traj, well_dict, 'B3', '22956814', "../22956814/B3_mask_seq_7.npy", 7)
b3_8 = make_lineage(traj, well_dict, 'B3', '22956814', "../22956814/B3_mask_seq_8.npy", 8)

b4_1 = make_lineage(traj, well_dict, 'B4', '22956814', "../22956814/B4_mask_seq_1.npy", 1)
b4_2 = make_lineage(traj, well_dict, 'B4', '22956814', "../22956814/B4_mask_seq_2.npy", 2)
b4_3 = make_lineage(traj, well_dict, 'B4', '22956814', "../22956814/B4_mask_seq_3.npy", 3)

c1_1 = make_lineage(traj, well_dict, 'C1', '22956814', "../22956814/C1_mask_seq_1.npy", 1)
c1_2 = make_lineage(traj, well_dict, 'C1', '22956814', "../22956814/C1_mask_seq_2.npy", 2)
c1_3 = make_lineage(traj, well_dict, 'C1', '22956814', "../22956814/C1_mask_seq_3.npy", 3)
c1_4 = make_lineage(traj, well_dict, 'C1', '22956814', "../22956814/C1_mask_seq_4.npy", 4)
c1_5 = make_lineage(traj, well_dict, 'C1', '22956814', "../22956814/C1_mask_seq_5.npy", 5)
c1_6 = make_lineage(traj, well_dict, 'C1', '22956814', "../22956814/C1_mask_seq_6.npy", 6)
c1_7 = make_lineage(traj, well_dict, 'C1', '22956814', "../22956814/C1_mask_seq_7.npy", 7)

c2_1 = make_lineage(traj, well_dict, 'C2', '22956814', "../22956814/C2_mask_seq_1.npy", 1)
c2_2 = make_lineage(traj, well_dict, 'C2', '22956814', "../22956814/C2_mask_seq_2.npy", 2)

c3_1 = make_lineage(traj, well_dict, 'C3', '22956814', "../22956814/C3_mask_seq_1.npy", 1)
c3_2 = make_lineage(traj, well_dict, 'C3', '22956814', "../22956814/C3_mask_seq_2.npy", 2)
c3_3 = make_lineage(traj, well_dict, 'C3', '22956814', "../22956814/C3_mask_seq_3.npy", 3)

c4_1 = make_lineage(traj, well_dict, 'C4', '22956814', "../22956814/C4_mask_seq_1.npy", 1)
c4_2 = make_lineage(traj, well_dict, 'C4', '22956814', "../22956814/C4_mask_seq_2.npy", 2)

d1_1 = make_lineage(traj, well_dict, 'D1', '22956814', "../22956814/D1_mask_seq_1.npy", 1)
d1_2 = make_lineage(traj, well_dict, 'D1', '22956814', "../22956814/D1_mask_seq_2.npy", 2)
d1_3 = make_lineage(traj, well_dict, 'D1', '22956814', "../22956814/D1_mask_seq_3.npy", 3)
d1_4 = make_lineage(traj, well_dict, 'D1', '22956814', "../22956814/D1_mask_seq_4.npy", 4)

d2_1 = make_lineage(traj, well_dict, 'D2', '22956814', "../22956814/D2_mask_seq_1.npy", 1)
d2_2 = make_lineage(traj, well_dict, 'D2', '22956814', "../22956814/D2_mask_seq_2.npy", 2)

d3_1 = make_lineage(traj, well_dict, 'D3', '22956814', "../22956814/D3_mask_seq_1.npy", 1)
d3_2 = make_lineage(traj, well_dict, 'D3', '22956814', "../22956814/D3_mask_seq_2.npy", 2)
d3_3 = make_lineage(traj, well_dict, 'D3', '22956814', "../22956814/D3_mask_seq_3.npy", 3)
d3_4 = make_lineage(traj, well_dict, 'D3', '22956814', "../22956814/D3_mask_seq_4.npy", 4)
d3_5 = make_lineage(traj, well_dict, 'D3', '22956814', "../22956814/D3_mask_seq_5.npy", 5)
d3_6 = make_lineage(traj, well_dict, 'D3', '22956814', "../22956814/D3_mask_seq_6.npy", 6)
d3_7 = make_lineage(traj, well_dict, 'D3', '22956814', "../22956814/D3_mask_seq_7.npy", 7)
d3_8 = make_lineage(traj, well_dict, 'D3', '22956814', "../22956814/D3_mask_seq_8.npy", 8)
d3_9 = make_lineage(traj, well_dict, 'D3', '22956814', "../22956814/D3_mask_seq_9.npy", 9)
d3_10 = make_lineage(traj, well_dict, 'D3', '22956814', "../22956814/D3_mask_seq_10.npy", 10)
d3_11 = make_lineage(traj, well_dict, 'D3', '22956814', "../22956814/D3_mask_seq_11.npy", 11)

d4_1 = make_lineage(traj, well_dict, 'D4', '22956814', "../22956814/D4_mask_seq_1.npy", 1)
d4_2 = make_lineage(traj, well_dict, 'D4', '22956814', "../22956814/D4_mask_seq_2.npy", 2)
d4_3 = make_lineage(traj, well_dict, 'D4', '22956814', "../22956814/D4_mask_seq_3.npy", 3)
d4_4 = make_lineage(traj, well_dict, 'D4', '22956814', "../22956814/D4_mask_seq_4.npy", 4)
d4_5 = make_lineage(traj, well_dict, 'D4', '22956814', "../22956814/D4_mask_seq_5.npy", 5)
d4_6 = make_lineage(traj, well_dict, 'D4', '22956814', "../22956814/D4_mask_seq_6.npy", 6)
d4_7 = make_lineage(traj, well_dict, 'D4', '22956814', "../22956814/D4_mask_seq_7.npy", 7)
d4_8 = make_lineage(traj, well_dict, 'D4', '22956814', "../22956814/D4_mask_seq_8.npy", 8)
d4_9 = make_lineage(traj, well_dict, 'D4', '22956814', "../22956814/D4_mask_seq_9.npy", 9)
d4_10 = make_lineage(traj, well_dict, 'D4', '22956814', "../22956814/D4_mask_seq_10.npy", 10)
d4_11 = make_lineage(traj, well_dict, 'D4', '22956814', "../22956814/D4_mask_seq_11.npy", 11)
d4_12 = make_lineage(traj, well_dict, 'D4', '22956814', "../22956814/D4_mask_seq_12.npy", 12)

# %%
lineages = [
    a1_1,
    a2_1,
    a2_2,
    a2_3,
    a2_4,
    a2_5,
    a3_1,
    a3_2,
    a3_3,
    a3_4,
    a3_5,
    a4_1,
    a4_2,
    a4_3,
    a4_4,
    a4_5,
    b1_1,
    b2_1,
    b2_2,
    b3_1,
    b3_2,
    b3_3,
    b3_4,
    b3_5,
    b3_6,
    b3_7,
    b3_8,
    b4_1,
    b4_2,
    b4_3,
    c1_1,
    c1_2,
    c1_3,
    c1_4,
    c1_5,
    c1_6,
    c1_7,
    c2_1,
    c2_2,
    c3_1,
    c3_2,
    c3_3,
    c4_1,
    c4_2,
    d1_1,
    d1_2,
    d1_3,
    d1_4,
    d2_1,
    d2_2,
    d3_1,
    d3_2,
    d3_3,
    d3_4,
    d3_5,
    d3_6,
    d3_7,
    d3_8,
    d3_9,
    d3_10,
    d3_11,
    d4_1,
    d4_2,
    d4_3,
    d4_4,
    d4_5,
    d4_6,
    d4_7,
    d4_8,
    d4_9,
    d4_10,
    d4_11,
    d4_12
]

# %%
# Load them all into .trks

masks_fn = [
    "../22956814/A1_mask_seq_1.npy",
    "../22956814/A2_mask_seq_1.npy",
    "../22956814/A2_mask_seq_2.npy",
    "../22956814/A2_mask_seq_3.npy",
    "../22956814/A2_mask_seq_4.npy",
    "../22956814/A2_mask_seq_5.npy",
    "../22956814/A3_mask_seq_1.npy",
    "../22956814/A3_mask_seq_2.npy",
    "../22956814/A3_mask_seq_3.npy",
    "../22956814/A3_mask_seq_4.npy",
    "../22956814/A3_mask_seq_5.npy",
    "../22956814/A4_mask_seq_1.npy",
    "../22956814/A4_mask_seq_2.npy",
    "../22956814/A4_mask_seq_3.npy",
    "../22956814/A4_mask_seq_4.npy",
    "../22956814/A4_mask_seq_5.npy",
    "../22956814/B1_mask_seq_1.npy",
    "../22956814/B2_mask_seq_1.npy",
    "../22956814/B2_mask_seq_2.npy",
    "../22956814/B3_mask_seq_1.npy",
    "../22956814/B3_mask_seq_2.npy",
    "../22956814/B3_mask_seq_3.npy",
    "../22956814/B3_mask_seq_4.npy",
    "../22956814/B3_mask_seq_5.npy",
    "../22956814/B3_mask_seq_6.npy",
    "../22956814/B3_mask_seq_7.npy",
    "../22956814/B3_mask_seq_8.npy",
    "../22956814/B4_mask_seq_1.npy",
    "../22956814/B4_mask_seq_2.npy",
    "../22956814/B4_mask_seq_3.npy",
    "../22956814/C1_mask_seq_1.npy",
    "../22956814/C1_mask_seq_2.npy",
    "../22956814/C1_mask_seq_3.npy",
    "../22956814/C1_mask_seq_4.npy",
    "../22956814/C1_mask_seq_5.npy",
    "../22956814/C1_mask_seq_6.npy",
    "../22956814/C1_mask_seq_7.npy",
    "../22956814/C2_mask_seq_1.npy",
    "../22956814/C2_mask_seq_2.npy",
    "../22956814/C3_mask_seq_1.npy",
    "../22956814/C3_mask_seq_2.npy",
    "../22956814/C3_mask_seq_3.npy",
    "../22956814/C4_mask_seq_1.npy",
    "../22956814/C4_mask_seq_2.npy",
    "../22956814/D1_mask_seq_1.npy",
    "../22956814/D1_mask_seq_2.npy",
    "../22956814/D1_mask_seq_3.npy",
    "../22956814/D1_mask_seq_4.npy",
    "../22956814/D2_mask_seq_1.npy",
    "../22956814/D2_mask_seq_2.npy",
    "../22956814/D3_mask_seq_1.npy",
    "../22956814/D3_mask_seq_2.npy",
    "../22956814/D3_mask_seq_3.npy",
    "../22956814/D3_mask_seq_4.npy",
    "../22956814/D3_mask_seq_5.npy",
    "../22956814/D3_mask_seq_6.npy",
    "../22956814/D3_mask_seq_7.npy",
    "../22956814/D3_mask_seq_8.npy",
    "../22956814/D3_mask_seq_9.npy",
    "../22956814/D3_mask_seq_10.npy",
    "../22956814/D3_mask_seq_11.npy",
    "../22956814/D4_mask_seq_1.npy",
    "../22956814/D4_mask_seq_2.npy",
    "../22956814/D4_mask_seq_3.npy",
    "../22956814/D4_mask_seq_4.npy",
    "../22956814/D4_mask_seq_5.npy",
    "../22956814/D4_mask_seq_6.npy",
    "../22956814/D4_mask_seq_7.npy",
    "../22956814/D4_mask_seq_8.npy",
    "../22956814/D4_mask_seq_9.npy",
    "../22956814/D4_mask_seq_10.npy",
    "../22956814/D4_mask_seq_11.npy",
    "../22956814/D4_mask_seq_12.npy"
]

# %%
raws_fn = [
    "../22956814/A1_raw_1.npy",
    "../22956814/A2_raw_1.npy",
    "../22956814/A2_raw_2.npy",
    "../22956814/A2_raw_3.npy",
    "../22956814/A2_raw_4.npy",
    "../22956814/A2_raw_5.npy",
    "../22956814/A3_raw_1.npy",
    "../22956814/A3_raw_2.npy",
    "../22956814/A3_raw_3.npy",
    "../22956814/A3_raw_4.npy",
    "../22956814/A3_raw_5.npy",
    "../22956814/A4_raw_1.npy",
    "../22956814/A4_raw_2.npy",
    "../22956814/A4_raw_3.npy",
    "../22956814/A4_raw_4.npy",
    "../22956814/A4_raw_5.npy",
    "../22956814/B1_raw_1.npy",
    "../22956814/B2_raw_1.npy",
    "../22956814/B2_raw_2.npy",
    "../22956814/B3_raw_1.npy",
    "../22956814/B3_raw_2.npy",
    "../22956814/B3_raw_3.npy",
    "../22956814/B3_raw_4.npy",
    "../22956814/B3_raw_5.npy",
    "../22956814/B3_raw_6.npy",
    "../22956814/B3_raw_7.npy",
    "../22956814/B3_raw_8.npy",
    "../22956814/B4_raw_1.npy",
    "../22956814/B4_raw_2.npy",
    "../22956814/B4_raw_3.npy",
    "../22956814/C1_raw_1.npy",
    "../22956814/C1_raw_2.npy",
    "../22956814/C1_raw_3.npy",
    "../22956814/C1_raw_4.npy",
    "../22956814/C1_raw_5.npy",
    "../22956814/C1_raw_6.npy",
    "../22956814/C1_raw_7.npy",
    "../22956814/C2_raw_1.npy",
    "../22956814/C2_raw_2.npy",
    "../22956814/C3_raw_1.npy",
    "../22956814/C3_raw_2.npy",
    "../22956814/C3_raw_3.npy",
    "../22956814/C4_raw_1.npy",
    "../22956814/C4_raw_2.npy",
    "../22956814/D1_raw_1.npy",
    "../22956814/D1_raw_2.npy",
    "../22956814/D1_raw_3.npy",
    "../22956814/D1_raw_4.npy",
    "../22956814/D2_raw_1.npy",
    "../22956814/D2_raw_2.npy",
    "../22956814/D3_raw_1.npy",
    "../22956814/D3_raw_2.npy",
    "../22956814/D3_raw_3.npy",
    "../22956814/D3_raw_4.npy",
    "../22956814/D3_raw_5.npy",
    "../22956814/D3_raw_6.npy",
    "../22956814/D3_raw_7.npy",
    "../22956814/D3_raw_8.npy",
    "../22956814/D3_raw_9.npy",
    "../22956814/D3_raw_10.npy",
    "../22956814/D3_raw_11.npy",
    "../22956814/D4_raw_1.npy",
    "../22956814/D4_raw_2.npy",
    "../22956814/D4_raw_3.npy",
    "../22956814/D4_raw_4.npy",
    "../22956814/D4_raw_5.npy",
    "../22956814/D4_raw_6.npy",
    "../22956814/D4_raw_7.npy",
    "../22956814/D4_raw_8.npy",
    "../22956814/D4_raw_9.npy",
    "../22956814/D4_raw_10.npy",
    "../22956814/D4_raw_11.npy",
    "../22956814/D4_raw_12.npy"
]

# %%
y = []
y_indices = []

for i, mask in enumerate(masks_fn):
    mask_array = np.load(mask)
    if mask_array.shape[0] == 100:
        y.append(mask_array)
        y_indices.append(i)

X = []

for i in y_indices:
    raw_array = np.load(raws_fn[i])
    X.append(raw_array)
    
lineages_true = []

for i in y_indices:
    lineages_true.append(lineages[i])

print(len(y))
print(len(X))
print(len(lineages_true))
# Out:
# 26
# 26
# 26

# %%
save_trks("../22956814/22956814_seq.trks", lineages_true, X, y)
